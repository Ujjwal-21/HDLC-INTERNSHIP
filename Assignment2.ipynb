# %% [markdown]
# ## **ASSIGNMENT 2**
# Ujjwal Kanti Pramanick
#
# Reg No: 20BCE1714

# %% [markdown]
# Qestion:
# ![Screenshot 2022-08-21 at 5.51.34 PM.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
A1=np.array([11,33,22,44,66,55])
A2=np.array([10,30,20,40,60,50])
print(A1)
print(A2)
# Out:
# [11 33 22 44 66 55]
# [10 30 20 40 60 50]

# %%
print(A1[2:6])
# Out:
# [22 44 66 55]

# %%
newA1=A1.reshape(3,2)
print(newA1)

# %%
A3 = np.concatenate((A1, A2))
print(A3)
# Out:
# [11 33 22 44 66 55 10 30 20 40 60 50]

# %%
newarr = np.array_split(A1, 3)
print(newarr)
# Out:
# [array([11, 33]), array([22, 44]), array([66, 55])]

# %%
x = np.where(A1 == 44)
print(x)
# Out:
# (array([3]),)

# %%
even_no = np.where(A2%2 == 0)
print(even_no)
# Out:
# (array([0, 1, 2, 3, 4, 5]),)

# %%
print(np.sort(A2))
# Out:
# [10 20 30 40 50 60]

# %%
x = [True,True,False,False, False, True]
new_odd=A1[x]
print(new_odd)
# Out:
# [11 33 55]

# %% [markdown]
# ## THANK YOU
